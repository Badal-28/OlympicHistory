# %% [markdown]
# <a href="https://colab.research.google.com/github/Badal-28/OlympicHistory/blob/main/120yearshistory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('athlete_events.csv')

# %%
df.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %%
df.tail(10)
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 271106  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566    James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                      Piotr ya   M  27.0   176.0    59.0
# 271113  135570                      Piotr ya   M  27.0   176.0    59.0
# 271114  135571            Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571            Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 271106      Argentina  ARG  2004 Summer  2004  Summer          Athina
# ...

# %%
df.sample(5)
# Out:
#            ID                              Name Sex   Age  Height  Weight  \
# 53643   27508              Anne-Marie Demortire   F  22.0   158.0    56.0
# 170578  85721                   Nguyn Th nh Vin   F  15.0   172.0    60.0
# 41619   21462  Oksana Aleksandrovna Chusovitina   F  21.0   153.0    43.0
# 97383   49290                         Peter Hol   M  37.0     NaN     NaN
# 177524  89226                    Dismus Onyiego   M  26.0   177.0    58.0
#
#               Team  NOC        Games  Year  Season       City       Sport  \
# 53643       France  FRA  1960 Summer  1960  Summer       Roma  Gymnastics
# 170578     Vietnam  VIE  2012 Summer  2012  Summer     London    Swimming
# 41619   Uzbekistan  UZB  1996 Summer  1996  Summer    Atlanta  Gymnastics
# 97383       Norway  NOR  1920 Summer  1920  Summer  Antwerpen  Gymnastics
# 177524       Kenya  KEN  1972 Summer  1972  Summer     Munich    Shooting
#
#                                                     Event   Medal
# ...

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df.duplicated().any()
# Out:
# True

# %%
df=df.drop_duplicates()

# %%
numerical_df=df.select_dtypes(include=['number'])

# %%
numerical_df.corr()
# Out:
#               ID       Age    Height    Weight      Year
# ID      1.000000 -0.002861 -0.011080 -0.009177  0.011381
# Age    -0.002861  1.000000  0.138277  0.212192 -0.092779
# Height -0.011080  0.138277  1.000000  0.796230  0.047615
# Weight -0.009177  0.212192  0.796230  1.000000  0.019236
# Year    0.011381 -0.092779  0.047615  0.019236  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(numerical_df.corr())
# Out:
# <Axes: >

# %% [markdown]
# # **UNIVARIATE ANALYSIS**

# %%
df.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    195353
# F     74378
# Name: count, dtype: int64

# %%
sns.countplot(df,x='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
top=df['Sport'].value_counts().head(10)
top.index
# Out:
# Index(['Athletics', 'Gymnastics', 'Swimming', 'Shooting', 'Cycling', 'Fencing',
#        'Rowing', 'Cross Country Skiing', 'Alpine Skiing', 'Wrestling'],
#       dtype='object', name='Sport')

# %%
df['Sport'].value_counts().head(10).plot(kind='pie',autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=top.values,y=top.index)
plt.title("Number of Athletes")
plt.xlabel("Athletes")
plt.ylabel("Count")
plt.show()

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
sns.histplot(df,x='Age',bins=20,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].mean()
# Out:
# 25.454776204227084

# %%
df['Age'].max()
# Out:
# 97.0

# %%
df['Age'].min()
# Out:
# 10.0

# %% [markdown]
# # **UNIVARIATE ANALYSIS AND MULTIVARIATE ANALYSIS**

# %%
sns.scatterplot(x='Age',y='Height',hue='Sex',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
sns.barplot(x='Medal',y='Age',data=df)
# Out:
# <Axes: xlabel='Medal', ylabel='Age'>

# %%
sns.boxplot(x='Medal',y='Age',data=df)
# Out:
# <Axes: xlabel='Medal', ylabel='Age'>

# %%
pd.crosstab(df['Sex'],df['Medal'])
# Out:
# Medal  Bronze  Gold  Silver
# Sex
# F        3771  3747    3735
# M        9524  9622    9373

# %%
sns.heatmap(pd.crosstab(df['Sex'],df['Medal']))
# Out:
# <Axes: xlabel='Medal', ylabel='Sex'>

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df1=pd.crosstab(df['Team'],df['Medal'])

# %%
df1['Total']=df1['Bronze']+df1['Gold']+df1['Silver']

# %%
df1.sort_values(by='Total',ascending=False)
# Out:
# Medal          Bronze  Gold  Silver  Total
# Team
# United States    1233  2474    1512   5219
# Soviet Union      677  1058     716   2451
# Germany           678   679     627   1984
# Great Britain     572   519     582   1673
# France            577   455     518   1550
# ...               ...   ...     ...    ...
# Djibouti            1     0       0      1
# Guyana              1     0       0      1
# Potsdam             1     0       0      1
# Bonaparte           0     1       0      1
# Mignon-3            1     0       0      1
#
# [498 rows x 4 columns]

# %%
df2=df[df['Team']=='India']

# %%
s=df2.groupby('Year')['Medal'].count()

# %%
s.head(1)
# Out:
# Year
# 1900    2
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x=s.index,y=s.values)
# Out:
# <Axes: xlabel='Year'>

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
z=df['Name'].value_counts().reset_index()

# %%
z.columns=["Athlete","Count"]

# %%
z.sort_values(by=['Count'],ascending=False)
# Out:
#                          Athlete  Count
# 0       Heikki Ilmari Savolainen     39
# 1          Joseph "Josy" Stoffel     38
# 2            Ioannis Theofilakis     36
# 3                    Takashi Ono     33
# 4         Alexandros Theofilakis     32
# ...                          ...    ...
# 83208        Kelly Subbanand Rao      1
# 83207    Tmendembereliin Znbayan      1
# 83206              Ibrahim Turay      1
# 83205    Frank Sima Turay Tucker      1
# 134731   Pierre-Georges LeClercq      1
#
# [134732 rows x 2 columns]

# %%
sns.barplot(x='Count',y='Athlete',data=z.head(10))
# Out:
# <Axes: xlabel='Count', ylabel='Athlete'>

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
q=df.groupby(['City','Medal']).size().unstack()

# %%
q['Total']=q[['Bronze','Silver','Gold']].sum(axis=1)

# %%
q.sort_values(by='Total',ascending=False)
# Out:
# Medal                   Bronze  Gold  Silver  Total
# City
# London                    1214  1215    1195   3624
# Athina                     860   883     859   2602
# Los Angeles                706   726     691   2123
# Beijing                    710   671     667   2048
# Rio de Janeiro             703   665     655   2023
# Sydney                     680   663     661   2004
# Atlanta                    629   608     605   1842
# Barcelona                  604   559     549   1712
# Seoul                      549   520     513   1582
# Paris                      449   475     501   1425
# Moskva                     469   457     458   1384
# Montreal                   448   438     434   1320
# Antwerpen                  367   493     448   1308
# Munich                     419   404     392   1215
# Mexico City                358   359     340   1057
# Tokyo                      343   347     339   1029
# Stockholm                  312   338     327    977
# ...
